# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('IMG_soil_final_metadata.csv', index_col=0)
df.head()
# Out:
#                  Domain Sequencing Status  \
# taxon_oid
# 3300020080  *Microbiome   Permanent Draft
# 3300029276  *Microbiome   Permanent Draft
# 3300003159  *Microbiome   Permanent Draft
# 3300002864  *Microbiome   Permanent Draft
# 3300023438  *Microbiome          Finished
#
#                                                    Study Name  \
# taxon_oid
# 3300020080  Corn, switchgrass and miscanthus rhizosphere m...
# 3300029276  Effect of Agricultural Soil Managment Practice...
# 3300003159  Avena fatua rhizosphere microbial communities ...
# 3300002864  Avena fatua rhizosphere microbial communities ...
# 3300023438  Effect of Agricultural Soil Managment Practice...
#
#                                     Genome Name / Sample Name  \
# taxon_oid
# 3300020080  Corn rhizosphere microbial communities from Ke...
# 3300029276  Sorghum rhizosphere microbial communities from...
# 3300003159  Avena fatua rhizosphere microbial communities ...
# ...

# %%
with open('soil_taxon_oids.txt') as f:
    oids = [int(i.strip()) for i in f]

reindexed = df.reindex(oids)

reindexed.head()
# Out:
#                  Domain Sequencing Status  \
# taxon_oid
# 2001200001  *Microbiome          Finished
# 2032320004          NaN               NaN
# 2032320005  *Microbiome             Draft
# 2035918004  *Microbiome   Permanent Draft
# 2044078000  *Microbiome   Permanent Draft
#
#                                                    Study Name  \
# taxon_oid
# 2001200001  Soil microbial communities from Waseca County,...
# 2032320004                                                NaN
# 2032320005  Soil microbial communities from FACE and OTC s...
# 2035918004  Soil microbial communities from FACE and OTC s...
# 2044078000  Switchgrass, Maize and Miscanthus rhizosphere ...
#
#                                     Genome Name / Sample Name  \
# taxon_oid
# 2001200001  Soil microbial communities from Waseca County,...
# 2032320004                                                NaN
# 2032320005  Soil microbial communities from sample at FACE...
# ...

# %%
not_null = reindexed[~pd.isnull(reindexed).all(axis=1)]
not_null.shape
# Out:
# (2281, 24)

# %%
other = df.reindex(df.index.difference(not_null.index))

# %%
other[other["Is Public"]=="No"]
# Out:
# Empty DataFrame
# Columns: [Domain, Sequencing Status, Study Name, Genome Name / Sample Name, Sequencing Center, IMG Genome ID , Is Public, NCBI Assembly Accession, NCBI Bioproject Accession, NCBI Biosample Accession, NCBI GenBank ID, Ecosystem, Ecosystem Category, Ecosystem Subtype, Ecosystem Type, Specific Ecosystem, Geographic Location, Isolation Country, Latitude, Longitude, Genome Size   * assembled, Gene Count   * assembled, Unnamed: 23, Study_type]
# Index: []
#
# [0 rows x 24 columns]
