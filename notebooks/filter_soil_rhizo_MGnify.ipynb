# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
df = pd.read_csv('../MGnify_all_metadata/mgnify_most_metadata_merged.csv')

df.head()
# Out:
# /tmp/ipykernel_1784551/63696278.py:1: DtypeWarning: Columns (24,25,27,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../MGnify_all_metadata/mgnify_most_metadata_merged.csv')
#    type_analyses   id_analyses attributes.accession_analyses  \
# 0  analysis-jobs  MGYA00000240                  MGYA00000240
# 1  analysis-jobs  MGYA00000241                  MGYA00000241
# 2  analysis-jobs  MGYA00000242                  MGYA00000242
# 3  analysis-jobs  MGYA00000243                  MGYA00000243
# 4  analysis-jobs  MGYA00000244                  MGYA00000244
#
#   attributes.analysis-status  \
# 0                  completed
# 1                  completed
# 2                  completed
# 3                  completed
# 4                  completed
#
#                          attributes.analysis-summary  \
# 0  [{'key': 'Submitted nucleotide sequences', 'va...
# 1  [{'key': 'Submitted nucleotide sequences', 'va...
# ...

# %%
df['attributes.experiment-type'].unique()
# Out:
# array(['metagenomic', 'metatranscriptomic', 'assembly', 'amplicon',
#        'unknown', 'metabarcoding', 'long_reads_assembly',
#        'hybrid_assembly'], dtype=object)

# %%
# Get rid of Unknown and Amplicon studies

df_meta = df[~df['attributes.experiment-type'].str.contains('amplicon|unknown|metabarcoding')]

df_soil_rhizo = df_meta[(df_meta['relationships.biome.data.id'].str.contains('root:Environmental:Terrestrial:Soil')) | (df_meta['relationships.biome.data.id'].str.contains('root:Host-associated:Plants:Rhizosphere'))]

#Only get the public data
df_soil_rhizo = df_soil_rhizo[df_soil_rhizo['attributes.is-private']==False]

# %%
#df_soil_rhizo.to_csv('MGnify_soil_rhizo_full_metadata.csv', index=None)

# %%
df_soil_rhizo[df_soil_rhizo['attributes.experiment-type'].str.contains('assembly')].shape
# Out:
# (334, 36)
